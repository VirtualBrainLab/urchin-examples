# %%
import oursin as urchin

# %%
urchin.setup()
# Out:
# (URN) connected to server
# Login sent with ID: 5c17e6b1, copy this ID into the renderer to connect.

# %%
urchin.human500.load()
# Out:
# (Warning) Atlas was already loaded, the renderer can have issues if you try to load an atlas twice.

# %%
urchin.human500.load_defaults()

# %%
urchin.azba8.load()

# %%
urchin.azba8.load_defaults()

# %%
urchin.azba8.root.set_visibility(True)
urchin.azba8.root.set_color("#808080")

# %%
urchin.azba8.data
# Out:
# AtlasModel(name='azba8', reference_coord=None, areas=[StructureModel(name='root', acronym='root', atlas_id=9999, color=Color(r=1.0, g=0.0, b=0.0, a=1), visible=False, color_intensity=-1, side=0, material='default'), StructureModel(name='anterior thalamic nucleus', acronym='A', atlas_id=1, color=Color(r=0.25098039215686274, g=0.3333333333333333, b=0.5137254901960784, a=1), visible=False, color_intensity=-1, side=0, material='default'), StructureModel(name='anterior cerebellar tract', acronym='AC', atlas_id=2, color=Color(r=0.25882352941176473, g=0.4549019607843137, b=0.8666666666666667, a=1), visible=False, color_intensity=-1, side=0, material='default'), StructureModel(name='anterior lateral line nerves', acronym='ALLN', atlas_id=3, color=Color(r=0.12549019607843137, g=0.8470588235294118, b=0.06666666666666667, a=1), visible=False, color_intensity=-1, side=0, material='default'), StructureModel(name='anterior octaval nucleus', acronym='AON', atlas_id=4, color=Color(r=0.89019607843137
# ...
